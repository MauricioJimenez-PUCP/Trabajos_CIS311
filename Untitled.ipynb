# %%
import pandas as pd
import numpy as np
import altair as alt

import hola_ejemplo as he

# %%
he.hola("Mauricio")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-3e225dab2e1f> in <module>
# ----> 1 he.hola("Mauricio")
#
# NameError: name 'he' is not defined

# %%
def hola(nombre) :
    return print( "hola " + nombre)

# %%
hola("Mauricio")
# Out:
# hola Mauricio

# %%
# %load_ext autoreload
# %autoreload 2

# %%
he.SEED
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-eaf886fdfbdf> in <module>
# ----> 1 he.SEED
#
# NameError: name 'he' is not defined
